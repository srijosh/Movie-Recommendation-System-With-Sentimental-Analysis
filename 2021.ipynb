# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9924\2513960026.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Extracting features of 2021 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9924\2803005693.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df1 = pd.read_html(str(tables[0]))[0]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9924\2803005693.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df2 = pd.read_html(str(tables[1]))[0]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9924\2803005693.py:3: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df3 = pd.read_html(str(tables[2]))[0]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9924\2803005693.py:4: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                            Title  \
# 0      J A N U A R Y        1.0              Shadow in the Cloud
# 1      J A N U A R Y        5.0                          Hacksaw
# 2      J A N U A R Y       12.0  Dr. Bird's Advice for Sad Poets
# 3      J A N U A R Y       13.0                  The White Tiger
# 4      J A N U A R Y       14.0                      Locked Down
# ..               ...        ...                              ...
# 359  D E C E M B E R       25.0           The Tragedy of Macbeth
# 360  D E C E M B E R       25.0             A Journal for Jordan
# 361  D E C E M B E R       25.0                American Underdog
# 362  D E C E M B E R       26.0                          Memoria
# 363  D E C E M B E R        NaN                              NaN
#
#                                     Production company  \
# 0                               Vertical Entertainment
# 1                     Leone Films / Midnight Releasing
# 2             Relativity Media / Ketchup Entertainment
# 3             Netflix / ARRAY / Purple Pebble Pictures
# 4                      HBO Max / Warner Bros. Pictures
# ..                                                 ...
# 359                        Apple TV+ / A24 / IAC Films
# 360  Columbia Pictures / Escape Artists / Bron Studios
# 361                                          Lionsgate
# 362                                               Neon
# 363                                                NaN
#
#                                          Cast and crew   Ref.
# 0    Roseanne Liang (director/screenplay); Max Land...    [2]
# 1    Anthony Leone (director/screenplay); Amy Cay, ...    [3]
# 2    Yaniv Raz (director/screenplay); Lucas Jade Zu...    [4]
# 3    Ramin Bahrani (director/screenplay); Adarsh Go...    NaN
# 4    Doug Liman (director); Steven Knight (screenpl...    [5]
# ..                                                 ...    ...
# 359  Joel Coen (director/screenplay); Denzel Washin...  [276]
# 360  Denzel Washington (director); Virgil Williams ...  [277]
# 361  Erwin brothers (directors); Jon Erwin, David A...  [278]
# 362  Apichatpong Weerasethakul (director/acreenplay...  [279]
# 363                                                NaN    NaN
#
# [364 rows x 6 columns]

# %%
df_2021 = df[['Title','Cast and crew']]

# %%
df_2021
# Out:
#                                Title  \
# 0                Shadow in the Cloud
# 1                            Hacksaw
# 2    Dr. Bird's Advice for Sad Poets
# 3                    The White Tiger
# 4                        Locked Down
# ..                               ...
# 359           The Tragedy of Macbeth
# 360             A Journal for Jordan
# 361                American Underdog
# 362                          Memoria
# 363                              NaN
#
#                                          Cast and crew
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Anthony Leone (director/screenplay); Amy Cay, ...
# 2    Yaniv Raz (director/screenplay); Lucas Jade Zu...
# 3    Ramin Bahrani (director/screenplay); Adarsh Go...
# 4    Doug Liman (director); Steven Knight (screenpl...
# ..                                                 ...
# 359  Joel Coen (director/screenplay); Denzel Washin...
# 360  Denzel Washington (director); Virgil Williams ...
# 361  Erwin brothers (directors); Jon Erwin, David A...
# 362  Apichatpong Weerasethakul (director/acreenplay...
# 363                                                NaN
#
# [364 rows x 2 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'YOUR_API_KEY'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    try:
        genres = []
        result = tmdb_movie.search(x)
        if not result:
            return np.NaN
        else:
            movie_id = result[0].id
            response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
            data_json = response.json()
            if data_json['genres']:
                genre_str = " " 
                for i in range(0, len(data_json['genres'])):
                    genres.append(data_json['genres'][i]['name'])
                return genre_str.join(genres)
            else:
                return np.NaN
    except Exception as e:
        return np.NaN

# %%
df_2021['genres'] =df_2021['Title'].map(lambda x: get_genre(str(x)))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9924\1039926252.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['genres'] =df_2021['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2021
# Out:
#                                Title  \
# 0                Shadow in the Cloud
# 1                            Hacksaw
# 2    Dr. Bird's Advice for Sad Poets
# 3                    The White Tiger
# 4                        Locked Down
# ..                               ...
# 359           The Tragedy of Macbeth
# 360             A Journal for Jordan
# 361                American Underdog
# 362                          Memoria
# 363                              NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Anthony Leone (director/screenplay); Amy Cay, ...
# 2    Yaniv Raz (director/screenplay); Lucas Jade Zu...
# 3    Ramin Bahrani (director/screenplay); Adarsh Go...
# 4    Doug Liman (director); Steven Knight (screenpl...
# ..                                                 ...
# 359  Joel Coen (director/screenplay); Denzel Washin...
# 360  Denzel Washington (director); Virgil Williams ...
# 361  Erwin brothers (directors); Jon Erwin, David A...
# 362  Apichatpong Weerasethakul (director/acreenplay...
# 363                                                NaN
#
#                             genres
# 0                Horror Action War
# 1                           Horror
# 2                     Comedy Drama
# 3                            Drama
# 4             Comedy Crime Romance
# ..                             ...
# 359                      Drama War
# 360                  Drama Romance
# 361                          Drama
# 362  Drama Science Fiction Mystery
# 363                    Drama Crime
#
# [364 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9924\2408679659.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['director_name'] = df_2021['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9924\708487029.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2021['actor_1_name'] = df_2021['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2021['actor_2_name'] = df_2021['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2021['actor_3_name'] = df_2021['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2021
# Out:
#                                Title  \
# 0                Shadow in the Cloud
# 1                            Hacksaw
# 2    Dr. Bird's Advice for Sad Poets
# 3                    The White Tiger
# 4                        Locked Down
# ..                               ...
# 359           The Tragedy of Macbeth
# 360             A Journal for Jordan
# 361                American Underdog
# 362                          Memoria
# 363                              NaN
#
#                                          Cast and crew  \
# 0    Roseanne Liang (director/screenplay); Max Land...
# 1    Anthony Leone (director/screenplay); Amy Cay, ...
# 2    Yaniv Raz (director/screenplay); Lucas Jade Zu...
# 3    Ramin Bahrani (director/screenplay); Adarsh Go...
# 4    Doug Liman (director); Steven Knight (screenpl...
# ..                                                 ...
# 359  Joel Coen (director/screenplay); Denzel Washin...
# 360  Denzel Washington (director); Virgil Williams ...
# 361  Erwin brothers (directors); Jon Erwin, David A...
# 362  Apichatpong Weerasethakul (director/acreenplay...
# 363                                                NaN
#
#                             genres  \
# 0                Horror Action War
# 1                           Horror
# 2                     Comedy Drama
# 3                            Drama
# 4             Comedy Crime Romance
# ..                             ...
# 359                      Drama War
# 360                  Drama Romance
# 361                          Drama
# 362  Drama Science Fiction Mystery
# 363                    Drama Crime
#
#                                          director_name  \
# 0                                       Roseanne Liang
# 1                                        Anthony Leone
# 2                                            Yaniv Raz
# 3                                        Ramin Bahrani
# 4                                           Doug Liman
# ..                                                 ...
# 359                                          Joel Coen
# 360                                  Denzel Washington
# 361                                     Erwin brothers
# 362  Apichatpong Weerasethakul (director/acreenplay...
# 363                                                nan
#
#                                           actor_1_name          actor_2_name  \
# 0                                   Chloë Grace Moretz     Taylor John Smith
# 1                                              Amy Cay  Brian Patrick Butler
# 2                                    Lucas Jade Zumann        Taylor Russell
# 3                                        Adarsh Gourav         Rajkummar Rao
# 4                                        Anne Hathaway      Chiwetel Ejiofor
# ..                                                 ...                   ...
# 359                                  Denzel Washington     Frances McDormand
# 360                                  Michael B. Jordan          Chanté Adams
# 361                                       Zachary Levi           Anna Paquin
# 362  Apichatpong Weerasethakul (director/acreenplay...            Elkin Díaz
# 363                                                nan                   NaN
#
#               actor_3_name
# 0             Beulah Koale
# 1       Michael C. Burgess
# 2             Chase Stokes
# 3    Priyanka Chopra Jonas
# 4         Stephen Merchant
# ..                     ...
# 359          Bertie Carvel
# 360        Jalon Christian
# 361           Dennis Quaid
# 362         Jeanne Balibar
# 363                    NaN
#
# [364 rows x 7 columns]

# %%
df_2021 = df_2021.rename(columns={'Title':'movie_title'})

# %%
new_df21 = df_2021.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df21
# Out:
#                                          director_name  \
# 0                                       Roseanne Liang
# 1                                        Anthony Leone
# 2                                            Yaniv Raz
# 3                                        Ramin Bahrani
# 4                                           Doug Liman
# ..                                                 ...
# 359                                          Joel Coen
# 360                                  Denzel Washington
# 361                                     Erwin brothers
# 362  Apichatpong Weerasethakul (director/acreenplay...
# 363                                                nan
#
#                                           actor_1_name          actor_2_name  \
# 0                                   Chloë Grace Moretz     Taylor John Smith
# 1                                              Amy Cay  Brian Patrick Butler
# 2                                    Lucas Jade Zumann        Taylor Russell
# 3                                        Adarsh Gourav         Rajkummar Rao
# 4                                        Anne Hathaway      Chiwetel Ejiofor
# ..                                                 ...                   ...
# 359                                  Denzel Washington     Frances McDormand
# 360                                  Michael B. Jordan          Chanté Adams
# 361                                       Zachary Levi           Anna Paquin
# 362  Apichatpong Weerasethakul (director/acreenplay...            Elkin Díaz
# 363                                                nan                   NaN
#
#               actor_3_name                         genres  \
# 0             Beulah Koale              Horror Action War
# 1       Michael C. Burgess                         Horror
# 2             Chase Stokes                   Comedy Drama
# 3    Priyanka Chopra Jonas                          Drama
# 4         Stephen Merchant           Comedy Crime Romance
# ..                     ...                            ...
# 359          Bertie Carvel                      Drama War
# 360        Jalon Christian                  Drama Romance
# 361           Dennis Quaid                          Drama
# 362         Jeanne Balibar  Drama Science Fiction Mystery
# 363                    NaN                    Drama Crime
#
#                          movie_title
# 0                Shadow in the Cloud
# 1                            Hacksaw
# 2    Dr. Bird's Advice for Sad Poets
# 3                    The White Tiger
# 4                        Locked Down
# ..                               ...
# 359           The Tragedy of Macbeth
# 360             A Journal for Jordan
# 361                American Underdog
# 362                          Memoria
# 363                              NaN
#
# [364 rows x 6 columns]

# %%
new_df21['comb'] = new_df21['actor_1_name'] + ' ' + new_df21['actor_2_name'] + ' '+ new_df21['actor_3_name'] + ' '+ new_df21['director_name'] +' ' + new_df21['genres']

# %%
new_df21.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      8
# actor_3_name     26
# genres            1
# movie_title       1
# comb             27
# dtype: int64

# %%
new_df21 = new_df21.dropna(how='any')

# %%
new_df21.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df21['movie_title'] = new_df21['movie_title'].str.lower()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9924\2732271610.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df21['movie_title'] = new_df21['movie_title'].str.lower()

# %%
new_df21
# Out:
#                                          director_name  \
# 0                                       Roseanne Liang
# 1                                        Anthony Leone
# 2                                            Yaniv Raz
# 3                                        Ramin Bahrani
# 4                                           Doug Liman
# ..                                                 ...
# 358                                     Matthew Vaughn
# 359                                          Joel Coen
# 360                                  Denzel Washington
# 361                                     Erwin brothers
# 362  Apichatpong Weerasethakul (director/acreenplay...
#
#                                           actor_1_name          actor_2_name  \
# 0                                   Chloë Grace Moretz     Taylor John Smith
# 1                                              Amy Cay  Brian Patrick Butler
# 2                                    Lucas Jade Zumann        Taylor Russell
# 3                                        Adarsh Gourav         Rajkummar Rao
# 4                                        Anne Hathaway      Chiwetel Ejiofor
# ..                                                 ...                   ...
# 358                                      Ralph Fiennes        Gemma Arterton
# 359                                  Denzel Washington     Frances McDormand
# 360                                  Michael B. Jordan          Chanté Adams
# 361                                       Zachary Levi           Anna Paquin
# 362  Apichatpong Weerasethakul (director/acreenplay...            Elkin Díaz
#
#               actor_3_name                            genres  \
# 0             Beulah Koale                 Horror Action War
# 1       Michael C. Burgess                            Horror
# 2             Chase Stokes                      Comedy Drama
# 3    Priyanka Chopra Jonas                             Drama
# 4         Stephen Merchant              Comedy Crime Romance
# ..                     ...                               ...
# 358             Rhys Ifans  Action Comedy Adventure Thriller
# 359          Bertie Carvel                         Drama War
# 360        Jalon Christian                     Drama Romance
# 361           Dennis Quaid                             Drama
# 362         Jeanne Balibar     Drama Science Fiction Mystery
#
#                          movie_title  \
# 0                shadow in the cloud
# 1                            hacksaw
# 2    dr. bird's advice for sad poets
# 3                    the white tiger
# 4                        locked down
# ..                               ...
# 358                   the king's man
# 359           the tragedy of macbeth
# 360             a journal for jordan
# 361                american underdog
# 362                          memoria
#
#                                                   comb
# 0    Chloë Grace Moretz Taylor John Smith Beulah Ko...
# 1    Amy Cay Brian Patrick Butler Michael C. Burges...
# 2    Lucas Jade Zumann Taylor Russell Chase Stokes ...
# 3    Adarsh Gourav Rajkummar Rao Priyanka Chopra Jo...
# 4    Anne Hathaway Chiwetel Ejiofor Stephen Merchan...
# ..                                                 ...
# 358  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 359  Denzel Washington Frances McDormand Bertie Car...
# 360  Michael B. Jordan Chanté Adams Jalon Christian...
# 361  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 362  Apichatpong Weerasethakul (director/acreenplay...
#
# [337 rows x 7 columns]

# %%
old_df = pd.read_csv('2020_and_prior.csv')

# %%
old_df
# Out:
#           director_name           actor_1_name      actor_2_name  \
# 0         James Cameron            CCH Pounder  Joel David Moore
# 1        Gore Verbinski            Johnny Depp     Orlando Bloom
# 2            Sam Mendes        Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan              Tom Hardy    Christian Bale
# 4           Doug Walker            Doug Walker        Rob Walker
# ...                 ...                    ...               ...
# 6091        Pete Docter             Jamie Foxx          Tina Fey
# 6092   Robert Rodriguez  Priyanka Chopra Jonas      Pedro Pascal
# 6093        Regina King      Kingsley Ben-Adir         Eli Goree
# 6094    Emerald Fennell         Carey Mulligan        Bo Burnham
# 6095   Kornél Mundruczó          Vanessa Kirby      Shia LaBeouf
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 6091         Graham Norton  Animation Family Comedy Fantasy
# 6092         YaYa Gosselin     Family Action Fantasy Comedy
# 6093           Aldis Hodge                            Drama
# 6094           Alison Brie             Thriller Crime Drama
# 6095          Molly Parker                            Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6091                                               soul
# 6092                                   we can be heroes
# 6093                              one night in miami...
# 6094                              promising young woman
# 6095                                  pieces of a woman
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6091  Jamie Foxx Tina Fey Graham Norton Pete Docter ...
# 6092  Priyanka Chopra Jonas Pedro Pascal YaYa Gossel...
# 6093  Kingsley Ben-Adir Eli Goree Aldis Hodge Regina...
# 6094  Carey Mulligan Bo Burnham Alison Brie Emerald ...
# 6095  Vanessa Kirby Shia LaBeouf Molly Parker Kornél...
#
# [6096 rows x 7 columns]

# %%
final_df = pd.concat([old_df, new_df21], ignore_index=True)

# %%
final_df
# Out:
#                                           director_name  \
# 0                                         James Cameron
# 1                                        Gore Verbinski
# 2                                            Sam Mendes
# 3                                     Christopher Nolan
# 4                                           Doug Walker
# ...                                                 ...
# 6428                                     Matthew Vaughn
# 6429                                          Joel Coen
# 6430                                  Denzel Washington
# 6431                                     Erwin brothers
# 6432  Apichatpong Weerasethakul (director/acreenplay...
#
#                                            actor_1_name       actor_2_name  \
# 0                                           CCH Pounder   Joel David Moore
# 1                                           Johnny Depp      Orlando Bloom
# 2                                       Christoph Waltz       Rory Kinnear
# 3                                             Tom Hardy     Christian Bale
# 4                                           Doug Walker         Rob Walker
# ...                                                 ...                ...
# 6428                                      Ralph Fiennes     Gemma Arterton
# 6429                                  Denzel Washington  Frances McDormand
# 6430                                  Michael B. Jordan       Chanté Adams
# 6431                                       Zachary Levi        Anna Paquin
# 6432  Apichatpong Weerasethakul (director/acreenplay...         Elkin Díaz
#
#               actor_3_name                            genres  \
# 0                Wes Studi   Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport          Action Adventure Fantasy
# 2         Stephanie Sigman         Action Adventure Thriller
# 3     Joseph Gordon-Levitt                   Action Thriller
# 4                  unknown                       Documentary
# ...                    ...                               ...
# 6428            Rhys Ifans  Action Comedy Adventure Thriller
# 6429         Bertie Carvel                         Drama War
# 6430       Jalon Christian                     Drama Romance
# 6431          Dennis Quaid                             Drama
# 6432        Jeanne Balibar     Drama Science Fiction Mystery
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6428                                     the king's man
# 6429                             the tragedy of macbeth
# 6430                               a journal for jordan
# 6431                                  american underdog
# 6432                                            memoria
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6428  Ralph Fiennes Gemma Arterton Rhys Ifans Matthe...
# 6429  Denzel Washington Frances McDormand Bertie Car...
# 6430  Michael B. Jordan Chanté Adams Jalon Christian...
# 6431  Zachary Levi Anna Paquin Dennis Quaid Erwin br...
# 6432  Apichatpong Weerasethakul (director/acreenplay...
#
# [6433 rows x 7 columns]

# %%
final_df.to_csv('2021_and_prior.csv',index=False)
