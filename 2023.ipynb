# %%
import pandas as pd
import numpy as np
import requests
import bs4 as bs
import urllib.request
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9312\2513960026.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Extracting features of 2023 movies from Wikipedia

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2023"

# %%
source = urllib.request.urlopen(link).read()
soup = bs.BeautifulSoup(source,'lxml')

# %%
tables = soup.find_all('table',class_='wikitable sortable')

# %%
len(tables)
# Out:
# 4

# %%
df1 = pd.read_html(str(tables[0]))[0]
df2 = pd.read_html(str(tables[1]))[0]
df3 = pd.read_html(str(tables[2]))[0]
df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9312\2803005693.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df1 = pd.read_html(str(tables[0]))[0]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9312\2803005693.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df2 = pd.read_html(str(tables[1]))[0]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9312\2803005693.py:3: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df3 = pd.read_html(str(tables[2]))[0]
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9312\2803005693.py:4: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df4 = pd.read_html(str(tables[3]).replace("'1\"\'",'"1"'))[0] # avoided "ValueError: invalid literal for int() with base 10: '1"'

# %%
df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# %%
df
# Out:
#              Opening  Opening.1                 Title  \
# 0      J A N U A R Y          6                 M3GAN
# 1      J A N U A R Y          6           The Old Way
# 2      J A N U A R Y         11  The Devil Conspiracy
# 3      J A N U A R Y         13                 Plane
# 4      J A N U A R Y         13           House Party
# ..               ...        ...                   ...
# 337  D E C E M B E R         22                Memory
# 338  D E C E M B E R         25      The Color Purple
# 339  D E C E M B E R         25  The Boys in the Boat
# 340  D E C E M B E R         25               Ferrari
# 341  D E C E M B E R         29            Good Grief
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / A...
# 1                           Saban Films / Saturn Films
# 2                                 Samuel Goldwyn Films
# 3    Lionsgate / MadRiver Pictures / Di Bonaventura...
# 4              Warner Bros. Pictures / New Line Cinema
# ..                                                 ...
# 337                       Ketchup Entertainment / Mubi
# 338  Warner Bros. Pictures / Amblin Entertainment /...
# 339          Metro-Goldwyn-Mayer / Smokehouse Pictures
# 340            Neon / STXfilms / Ketchup Entertainment
# 341                                            Netflix
#
#                                          Cast and crew   Ref.
# 0    Gerard Johnstone (director); Akela Cooper (scr...    [3]
# 1    Brett Donowho (director); Carl W. Lucas (scree...    [4]
# 2    Nathan Frankowski (director); Ed Alan (screenp...    [5]
# 3    Jean-François Richet (director); Charles Cummi...    [6]
# 4    Calmatic (director); Jamal Olori, Stephen Glov...    [7]
# ..                                                 ...    ...
# 337  Michel Franco (director/screenplay); Jessica C...  [324]
# 338  Blitz Bazawule (director), Marcus Gardley (scr...  [325]
# 339  George Clooney (director), Mark L. Smith (scre...  [326]
# 340  Michael Mann (director), Troy Kennedy Martin (...  [327]
# 341  Dan Levy (director/screenplay); Dan Levy, Ruth...  [328]
#
# [342 rows x 6 columns]

# %%
df_2023 = df[['Title','Cast and crew']]

# %%
df_2023
# Out:
#                     Title                                      Cast and crew
# 0                   M3GAN  Gerard Johnstone (director); Akela Cooper (scr...
# 1             The Old Way  Brett Donowho (director); Carl W. Lucas (scree...
# 2    The Devil Conspiracy  Nathan Frankowski (director); Ed Alan (screenp...
# 3                   Plane  Jean-François Richet (director); Charles Cummi...
# 4             House Party  Calmatic (director); Jamal Olori, Stephen Glov...
# ..                    ...                                                ...
# 337                Memory  Michel Franco (director/screenplay); Jessica C...
# 338      The Color Purple  Blitz Bazawule (director), Marcus Gardley (scr...
# 339  The Boys in the Boat  George Clooney (director), Mark L. Smith (scre...
# 340               Ferrari  Michael Mann (director), Troy Kennedy Martin (...
# 341            Good Grief  Dan Levy (director/screenplay); Dan Levy, Ruth...
#
# [342 rows x 2 columns]

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = 'YOUR_API_KEY'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie() 
def get_genre(x):
    try:
        genres = []
        result = tmdb_movie.search(x)
        if not result:
            return np.NaN
        else:
            movie_id = result[0].id
            response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id, tmdb.api_key))
            data_json = response.json()
            if data_json['genres']:
                genre_str = " " 
                for i in range(0, len(data_json['genres'])):
                    genres.append(data_json['genres'][i]['name'])
                return genre_str.join(genres)
            else:
                return np.NaN
    except Exception as e:
        return np.NaN

# %%
df_2023['genres'] =df_2023['Title'].map(lambda x: get_genre(str(x)))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9312\620867732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023['genres'] =df_2023['Title'].map(lambda x: get_genre(str(x)))

# %%
df_2023
# Out:
#                     Title                                      Cast and crew  \
# 0                   M3GAN  Gerard Johnstone (director); Akela Cooper (scr...
# 1             The Old Way  Brett Donowho (director); Carl W. Lucas (scree...
# 2    The Devil Conspiracy  Nathan Frankowski (director); Ed Alan (screenp...
# 3                   Plane  Jean-François Richet (director); Charles Cummi...
# 4             House Party  Calmatic (director); Jamal Olori, Stephen Glov...
# ..                    ...                                                ...
# 337                Memory  Michel Franco (director/screenplay); Jessica C...
# 338      The Color Purple  Blitz Bazawule (director), Marcus Gardley (scr...
# 339  The Boys in the Boat  George Clooney (director), Mark L. Smith (scre...
# 340               Ferrari  Michael Mann (director), Troy Kennedy Martin (...
# 341            Good Grief  Dan Levy (director/screenplay); Dan Levy, Ruth...
#
#                                       genres
# 0                     Science Fiction Horror
# 1                              Western Drama
# 2    Horror Fantasy Science Fiction Thriller
# 3                                     Action
# 4                                     Comedy
# ..                                       ...
# 337                    Action Thriller Crime
# 338                                    Drama
# 339                            Drama History
# 340                            History Drama
# 341                             Comedy Drama
#
# [342 rows x 3 columns]

# %%
def get_director(x):
    if " (director)" in x:
        return x.split(" (director)")[0]
    elif " (directors)" in x:
        return x.split(" (directors)")[0]
    else:
        return x.split(" (director/screenplay)")[0]

# %%
df_2023['director_name'] = df_2023['Cast and crew'].map(lambda x: get_director(str(x)))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9312\1437170397.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023['director_name'] = df_2023['Cast and crew'].map(lambda x: get_director(str(x)))

# %%
def get_actor1(x):
    return ((x.split("screenplay); ")[-1]).split(", ")[0])

# %%
df_2023['actor_1_name'] = df_2023['Cast and crew'].map(lambda x: get_actor1(str(x)))
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9312\3530219434.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2023['actor_1_name'] = df_2023['Cast and crew'].map(lambda x: get_actor1(str(x)))

# %%
def get_actor2(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 2:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[1])

# %%
df_2023['actor_2_name'] = df_2023['Cast and crew'].map(lambda x: get_actor2(str(x)))

# %%
def get_actor3(x):
    if len((x.split("screenplay); ")[-1]).split(", ")) < 3:
        return np.NaN
    else:
        return ((x.split("screenplay); ")[-1]).split(", ")[2])

# %%
df_2023['actor_3_name'] = df_2023['Cast and crew'].map(lambda x: get_actor3(str(x)))

# %%
df_2023
# Out:
#                     Title                                      Cast and crew  \
# 0                   M3GAN  Gerard Johnstone (director); Akela Cooper (scr...
# 1             The Old Way  Brett Donowho (director); Carl W. Lucas (scree...
# 2    The Devil Conspiracy  Nathan Frankowski (director); Ed Alan (screenp...
# 3                   Plane  Jean-François Richet (director); Charles Cummi...
# 4             House Party  Calmatic (director); Jamal Olori, Stephen Glov...
# ..                    ...                                                ...
# 337                Memory  Michel Franco (director/screenplay); Jessica C...
# 338      The Color Purple  Blitz Bazawule (director), Marcus Gardley (scr...
# 339  The Boys in the Boat  George Clooney (director), Mark L. Smith (scre...
# 340               Ferrari  Michael Mann (director), Troy Kennedy Martin (...
# 341            Good Grief  Dan Levy (director/screenplay); Dan Levy, Ruth...
#
#                                       genres         director_name  \
# 0                     Science Fiction Horror      Gerard Johnstone
# 1                              Western Drama         Brett Donowho
# 2    Horror Fantasy Science Fiction Thriller     Nathan Frankowski
# 3                                     Action  Jean-François Richet
# 4                                     Comedy              Calmatic
# ..                                       ...                   ...
# 337                    Action Thriller Crime         Michel Franco
# 338                                    Drama        Blitz Bazawule
# 339                            Drama History        George Clooney
# 340                            History Drama          Michael Mann
# 341                             Comedy Drama              Dan Levy
#
#          actor_1_name          actor_2_name      actor_3_name
# 0    Allison Williams         Violet McGraw       Amie Donald
# 1        Nicolas Cage  Ryan Kiera Armstrong               NaN
# 2     Alice Orr-Ewing             Joe Doyle      Eveline Hall
# 3       Gerard Butler           Mike Colter          Yoson An
# 4          Tosin Cole        Jacob Latimore      Karen Obilom
# ..                ...                   ...               ...
# 337  Jessica Chastain       Peter Sarsgaard     Merritt Wever
# 338  Fantasia Barrino      Taraji P. Henson   Danielle Brooks
# 339     Callum Turner         Joel Edgerton    Peter Guinness
# 340       Adam Driver         Penelope Cruz  Shailene Woodley
# 341          Dan Levy            Ruth Negga      Himesh Patel
#
# [342 rows x 7 columns]

# %%
df_2023 = df_2023.rename(columns={'Title':'movie_title'})

# %%
new_df23 = df_2023.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_df23
# Out:
#             director_name      actor_1_name          actor_2_name  \
# 0        Gerard Johnstone  Allison Williams         Violet McGraw
# 1           Brett Donowho      Nicolas Cage  Ryan Kiera Armstrong
# 2       Nathan Frankowski   Alice Orr-Ewing             Joe Doyle
# 3    Jean-François Richet     Gerard Butler           Mike Colter
# 4                Calmatic        Tosin Cole        Jacob Latimore
# ..                    ...               ...                   ...
# 337         Michel Franco  Jessica Chastain       Peter Sarsgaard
# 338        Blitz Bazawule  Fantasia Barrino      Taraji P. Henson
# 339        George Clooney     Callum Turner         Joel Edgerton
# 340          Michael Mann       Adam Driver         Penelope Cruz
# 341              Dan Levy          Dan Levy            Ruth Negga
#
#          actor_3_name                                   genres  \
# 0         Amie Donald                   Science Fiction Horror
# 1                 NaN                            Western Drama
# 2        Eveline Hall  Horror Fantasy Science Fiction Thriller
# 3            Yoson An                                   Action
# 4        Karen Obilom                                   Comedy
# ..                ...                                      ...
# 337     Merritt Wever                    Action Thriller Crime
# 338   Danielle Brooks                                    Drama
# 339    Peter Guinness                            Drama History
# 340  Shailene Woodley                            History Drama
# 341      Himesh Patel                             Comedy Drama
#
#               movie_title
# 0                   M3GAN
# 1             The Old Way
# 2    The Devil Conspiracy
# 3                   Plane
# 4             House Party
# ..                    ...
# 337                Memory
# 338      The Color Purple
# 339  The Boys in the Boat
# 340               Ferrari
# 341            Good Grief
#
# [342 rows x 6 columns]

# %%
new_df23['comb'] = new_df23['actor_1_name'] + ' ' + new_df23['actor_2_name'] + ' '+ new_df23['actor_3_name'] + ' '+ new_df23['director_name'] +' ' + new_df23['genres']

# %%
new_df23.isna().sum()
# Out:
# director_name     0
# actor_1_name      0
# actor_2_name      3
# actor_3_name     20
# genres            0
# movie_title       0
# comb             20
# dtype: int64

# %%
new_df23 = new_df23.dropna(how='any')

# %%
new_df23.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
new_df23['movie_title'] = new_df23['movie_title'].str.lower()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9312\3055323516.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df23['movie_title'] = new_df23['movie_title'].str.lower()

# %%
new_df23
# Out:
#             director_name      actor_1_name       actor_2_name  \
# 0        Gerard Johnstone  Allison Williams      Violet McGraw
# 2       Nathan Frankowski   Alice Orr-Ewing          Joe Doyle
# 3    Jean-François Richet     Gerard Butler        Mike Colter
# 4                Calmatic        Tosin Cole     Jacob Latimore
# 5              John Hyams      Gideon Adlon  Bethlehem Million
# ..                    ...               ...                ...
# 337         Michel Franco  Jessica Chastain    Peter Sarsgaard
# 338        Blitz Bazawule  Fantasia Barrino   Taraji P. Henson
# 339        George Clooney     Callum Turner      Joel Edgerton
# 340          Michael Mann       Adam Driver      Penelope Cruz
# 341              Dan Levy          Dan Levy         Ruth Negga
#
#          actor_3_name                                   genres  \
# 0         Amie Donald                   Science Fiction Horror
# 2        Eveline Hall  Horror Fantasy Science Fiction Thriller
# 3            Yoson An                                   Action
# 4        Karen Obilom                                   Comedy
# 5       Marc Menchaca                  Horror Thriller Mystery
# ..                ...                                      ...
# 337     Merritt Wever                    Action Thriller Crime
# 338   Danielle Brooks                                    Drama
# 339    Peter Guinness                            Drama History
# 340  Shailene Woodley                            History Drama
# 341      Himesh Patel                             Comedy Drama
#
#               movie_title                                               comb
# 0                   m3gan  Allison Williams Violet McGraw Amie Donald Ger...
# 2    the devil conspiracy  Alice Orr-Ewing Joe Doyle Eveline Hall Nathan ...
# 3                   plane  Gerard Butler Mike Colter Yoson An Jean-Franço...
# 4             house party  Tosin Cole Jacob Latimore Karen Obilom Calmati...
# 5                    sick  Gideon Adlon Bethlehem Million Marc Menchaca J...
# ..                    ...                                                ...
# 337                memory  Jessica Chastain Peter Sarsgaard Merritt Wever...
# 338      the color purple  Fantasia Barrino Taraji P. Henson Danielle Bro...
# 339  the boys in the boat  Callum Turner Joel Edgerton Peter Guinness Geo...
# 340               ferrari  Adam Driver Penelope Cruz Shailene Woodley Mic...
# 341            good grief  Dan Levy Ruth Negga Himesh Patel Dan Levy Come...
#
# [322 rows x 7 columns]

# %%
old_df = pd.read_csv('2022_and_prior.csv')

# %%
old_df
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 6709       Kasi Lemmons      Naomi Ackie     Stanley Tucci
# 6710       Scott Cooper   Christian Bale     Harry Melling
# 6711       Sarah Polley      Rooney Mara        Claire Foy
# 6712       Marc Forster        Tom Hanks   Mariana Treviño
# 6713         Mary Nighy    Anna Kendrick   Kaniehtiio Horn
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 6709        Ashton Sanders              Music History Drama
# 6710      Gillian Anderson    Thriller Crime Horror Mystery
# 6711        Jessie Buckley                      Drama Crime
# 6712         Rachel Keller                     Comedy Drama
# 6713       Charlie Carrick           Thriller Drama Romance
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 6709       whitney houston: i wanna dance with somebody
# 6710                                  the pale blue eye
# 6711                                      women talking
# 6712                                  a man called otto
# 6713                                     alice, darling
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 6709  Naomi Ackie Stanley Tucci Ashton Sanders Kasi ...
# 6710  Christian Bale Harry Melling Gillian Anderson ...
# 6711  Rooney Mara Claire Foy Jessie Buckley Sarah Po...
# 6712  Tom Hanks Mariana Treviño Rachel Keller Marc F...
# 6713  Anna Kendrick Kaniehtiio Horn Charlie Carrick ...
#
# [6714 rows x 7 columns]

# %%
final_df = pd.concat([old_df, new_df23], ignore_index=True)

# %%
final_df
# Out:
#           director_name      actor_1_name      actor_2_name  \
# 0         James Cameron       CCH Pounder  Joel David Moore
# 1        Gore Verbinski       Johnny Depp     Orlando Bloom
# 2            Sam Mendes   Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan         Tom Hardy    Christian Bale
# 4           Doug Walker       Doug Walker        Rob Walker
# ...                 ...               ...               ...
# 7031      Michel Franco  Jessica Chastain   Peter Sarsgaard
# 7032     Blitz Bazawule  Fantasia Barrino  Taraji P. Henson
# 7033     George Clooney     Callum Turner     Joel Edgerton
# 7034       Michael Mann       Adam Driver     Penelope Cruz
# 7035           Dan Levy          Dan Levy        Ruth Negga
#
#               actor_3_name                           genres  \
# 0                Wes Studi  Action Adventure Fantasy Sci-Fi
# 1           Jack Davenport         Action Adventure Fantasy
# 2         Stephanie Sigman        Action Adventure Thriller
# 3     Joseph Gordon-Levitt                  Action Thriller
# 4                  unknown                      Documentary
# ...                    ...                              ...
# 7031         Merritt Wever            Action Thriller Crime
# 7032       Danielle Brooks                            Drama
# 7033        Peter Guinness                    Drama History
# 7034      Shailene Woodley                    History Drama
# 7035          Himesh Patel                     Comedy Drama
#
#                                             movie_title  \
# 0                                                avatar
# 1              pirates of the caribbean: at world's end
# 2                                               spectre
# 3                                 the dark knight rises
# 4     star wars: episode vii - the force awakens    ...
# ...                                                 ...
# 7031                                             memory
# 7032                                   the color purple
# 7033                               the boys in the boat
# 7034                                            ferrari
# 7035                                         good grief
#
#                                                    comb
# 0     CCH Pounder Joel David Moore Wes Studi James C...
# 1     Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2     Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3     Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4     Doug Walker Rob Walker unknown Doug Walker Doc...
# ...                                                 ...
# 7031  Jessica Chastain Peter Sarsgaard Merritt Wever...
# 7032  Fantasia Barrino Taraji P. Henson Danielle Bro...
# 7033  Callum Turner Joel Edgerton Peter Guinness Geo...
# 7034  Adam Driver Penelope Cruz Shailene Woodley Mic...
# 7035  Dan Levy Ruth Negga Himesh Patel Dan Levy Come...
#
# [7036 rows x 7 columns]

# %%
final_df.to_csv('2023_and_prior.csv',index=False)
